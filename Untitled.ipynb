# %%
import xarray as xr
import cartopy.crs as ccrs

# %%
datapath = '/lus/scratch/shao/data/NEP36_extremes/'
ds = xr.open_mfdataset(
    f'{datapath}/processed/daily/by_year/1999.nc',
    parallel=True,
    engine='h5netcdf'
)

# %%
ds.mean('time').T.plot()
